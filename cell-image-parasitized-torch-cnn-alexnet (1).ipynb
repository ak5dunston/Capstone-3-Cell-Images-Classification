# %% [markdown]
# # Cell Image Parasitized Torch CNN/AlexNet

# %%
import os
import random
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torchvision.utils import make_grid

# %%
transform=transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
])

# %%
import opendatasets as od
import pandas
od.download(
"https://www.kaggle.com/datasets/brsdincer/cell-images-parasitized-or-not?resource=download&select=cell_images")
# Out:
# Skipping, found downloaded files in ".\cell-images-parasitized-or-not" (use force=True to force download)

# %% [markdown]
# # Train and Test Setting

# %%
train_ds=datasets.ImageFolder(root=(r".\cell-images-parasitized-or-not/cell_images/train"),transform=transform)
test_ds=datasets.ImageFolder(root=(r".\cell-images-parasitized-or-not/cell_images/test"),transform=transform)

# %%
class_names=train_ds.classes
print(class_names)
print(len(class_names))
# Out:
# ['parasitized', 'uninfected']
# 2

# %% [markdown]
# torch.manual_seed(10)
# test_size = len(dataset)//5
# train_size = len(dataset) - test_size
#
# train_ds, test_ds = random_split(dataset, [train_size, test_size])
# len(train_ds), len(test_ds)

# %%
train_loader=DataLoader(train_ds,batch_size=10,shuffle=True)
test_loader=DataLoader(test_ds,batch_size=10)

# %% [markdown]
# # Check Images and Labels

# %%
for images, labels in train_loader:
    break
#print the labels
print('Label:', labels.numpy())
print('Class:', *np.array([class_names[i] for i in labels]))

im=make_grid(images,nrow=5)
# Out:
# Label: [0 1 1 1 0 1 0 1 1 0]
# Class: parasitized uninfected uninfected uninfected parasitized uninfected parasitized uninfected uninfected parasitized

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
inv_normalize=transforms.Normalize(mean=[-0.485/0.229,-0.456/0.224,-0.406/0.225],
                                    std=[1/0.229,1/0.224,1/0.225])
im=inv_normalize(im)

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %% [markdown]
# # CNN Model

# %%
class MyCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1=nn.Conv2d(3,6,3,1)
        self.conv2=nn.Conv2d(6,16,3,1)
        self.fc1=nn.Linear(16*54*54,120)
        self.fc2=nn.Linear(120,84)
        self.fc3=nn.Linear(84,20)
        self.fc4=nn.Linear(20,2)
        
    def forward(self,X):
        X=F.relu(self.conv1(X))
        X=F.max_pool2d(X,2,2)
        X=F.relu(self.conv2(X))
        X=F.max_pool2d(X,2,2)
        X=X.view(-1,16*54*54)
        X=F.relu(self.fc1(X))
        X=F.relu(self.fc2(X))
        X=F.relu(self.fc3(X))
        X=self.fc4(X)
        X=F.log_softmax(X,dim=1)
        return X

# %%
mycnn=MyCNN()
criterion=nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(mycnn.parameters(),lr=0.001)

# %%
mycnn
# Out:
# MyCNN(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=46656, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=2, bias=True)
# )

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>8}')
    print(f'________\n{sum(params):>8}')
count_parameters(mycnn)
# Out:
#      162
#        6
#      864
#       16
#  5598720
#      120
#    10080
#       84
#     1680
#       20
#       40
#        2
# ________
#  5611794

# %%
import time
start_time=time.time()
train_losses=[]
test_losses=[]
train_correct=[]
test_correct=[]
epochs=10

for i in range(epochs):
    trn_corr=0
    tst_corr=0
    for b, (X_train,y_train) in enumerate(train_loader):
        b+=1                                            
        y_pred=mycnn(X_train)
        loss=criterion(y_pred,y_train)
        #true predictions
        predicted=torch.max(y_pred.data,1)[1]
        batch_corr=(predicted==y_train).sum()
        trn_corr+=batch_corr
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if b%200==0:
            print(f"epoch: {i} loss: {loss.item} batch: {b} accuracy: {trn_corr.item()*100/(10*b):7.3f}%")
    loss=loss.detach().numpy()
    train_losses.append(loss)
    train_correct.append(trn_corr)
    
    
    with torch.no_grad():
        for b, (X_test,y_test) in enumerate(test_loader):
            y_val=mycnn(X_test)
            loss=criterion(y_val,y_test)
            
            predicted=torch.max(y_val.data,1)[1]
            btach_corr=(predicted==y_test).sum()
            tst_corr+=btach_corr
            
        loss=loss.detach().numpy()
        test_losses.append(loss)
        test_correct.append(tst_corr)
        
print(f'\nDuration: {time.time() - start_time:.0f} seconds')
# Out:
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87AD0> batch: 200 accuracy:  62.100%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87F50> batch: 400 accuracy:  72.500%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87A70> batch: 600 accuracy:  78.417%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87E90> batch: 800 accuracy:  82.100%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87CB0> batch: 1000 accuracy:  84.110%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87E30> batch: 1200 accuracy:  85.400%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87AD0> batch: 1400 accuracy:  86.286%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87D70> batch: 1600 accuracy:  87.175%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E85F10> batch: 1800 accuracy:  86.517%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E86FF0> batch: 2000 accuracy:  87.155%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87170> batch: 2200 accuracy:  87.623%
# epoch: 0 loss: <built-in method item of Tensor object at 0x00000178A5E87A70> batch: 2400 accuracy:  88.075%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E878F0> batch: 200 accuracy:  92.950%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E872F0> batch: 400 accuracy:  92.725%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E87BF0> batch: 600 accuracy:  92.917%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E878F0> batch: 800 accuracy:  93.250%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E87D10> batch: 1000 accuracy:  93.280%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E87AD0> batch: 1200 accuracy:  93.342%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E86A50> batch: 1400 accuracy:  93.386%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E86A50> batch: 1600 accuracy:  93.438%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E87FB0> batch: 1800 accuracy:  93.339%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E86FF0> batch: 2000 accuracy:  93.345%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E862D0> batch: 2200 accuracy:  93.373%
# epoch: 1 loss: <built-in method item of Tensor object at 0x00000178A5E86B70> batch: 2400 accuracy:  93.362%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5A690> batch: 200 accuracy:  93.700%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5B8F0> batch: 400 accuracy:  93.975%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5B8F0> batch: 600 accuracy:  94.017%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5B8F0> batch: 800 accuracy:  93.725%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5BE90> batch: 1000 accuracy:  93.870%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5A690> batch: 1200 accuracy:  93.908%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5BD70> batch: 1400 accuracy:  93.907%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5BF50> batch: 1600 accuracy:  93.856%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5BD70> batch: 1800 accuracy:  93.772%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5BA70> batch: 2000 accuracy:  93.720%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5BF50> batch: 2200 accuracy:  93.718%
# epoch: 2 loss: <built-in method item of Tensor object at 0x00000178A5E5B7D0> batch: 2400 accuracy:  93.654%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5A1B0> batch: 200 accuracy:  93.850%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5B0B0> batch: 400 accuracy:  93.600%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E593D0> batch: 600 accuracy:  93.317%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E59A90> batch: 800 accuracy:  93.250%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5BA70> batch: 1000 accuracy:  93.480%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5A690> batch: 1200 accuracy:  93.417%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5AD50> batch: 1400 accuracy:  93.614%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5B470> batch: 1600 accuracy:  93.681%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5AD50> batch: 1800 accuracy:  93.689%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E5B0B0> batch: 2000 accuracy:  93.705%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E58E30> batch: 2200 accuracy:  93.805%
# epoch: 3 loss: <built-in method item of Tensor object at 0x00000178A5E59A90> batch: 2400 accuracy:  93.796%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5A690> batch: 200 accuracy:  93.600%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5A690> batch: 400 accuracy:  93.825%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 600 accuracy:  93.833%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5BD70> batch: 800 accuracy:  93.862%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5B0B0> batch: 1000 accuracy:  93.930%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E59490> batch: 1200 accuracy:  93.892%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5B650> batch: 1400 accuracy:  93.879%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 1600 accuracy:  93.675%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5BD70> batch: 1800 accuracy:  93.733%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E59490> batch: 2000 accuracy:  93.750%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 2200 accuracy:  93.795%
# epoch: 4 loss: <built-in method item of Tensor object at 0x00000178A5E5AD50> batch: 2400 accuracy:  93.829%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E58590> batch: 200 accuracy:  94.350%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 400 accuracy:  93.825%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E59A90> batch: 600 accuracy:  93.633%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E58590> batch: 800 accuracy:  93.713%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E59A90> batch: 1000 accuracy:  93.900%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E59B50> batch: 1200 accuracy:  93.858%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E5AD50> batch: 1400 accuracy:  93.764%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E5BD70> batch: 1600 accuracy:  93.844%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E591F0> batch: 1800 accuracy:  93.917%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E591F0> batch: 2000 accuracy:  93.985%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E5AD50> batch: 2200 accuracy:  94.109%
# epoch: 5 loss: <built-in method item of Tensor object at 0x00000178A5E5BEF0> batch: 2400 accuracy:  94.067%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E58110> batch: 200 accuracy:  94.350%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E58110> batch: 400 accuracy:  94.500%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 600 accuracy:  94.367%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E59B50> batch: 800 accuracy:  94.075%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E5B0B0> batch: 1000 accuracy:  94.120%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E5B890> batch: 1200 accuracy:  94.125%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E5BA70> batch: 1400 accuracy:  94.329%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E5B770> batch: 1600 accuracy:  94.381%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E58110> batch: 1800 accuracy:  94.389%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E58110> batch: 2000 accuracy:  94.275%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E5B0B0> batch: 2200 accuracy:  94.241%
# epoch: 6 loss: <built-in method item of Tensor object at 0x00000178A5E59A90> batch: 2400 accuracy:  94.275%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 200 accuracy:  94.450%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 400 accuracy:  94.625%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E5B650> batch: 600 accuracy:  94.450%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E5B770> batch: 800 accuracy:  94.588%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E59B50> batch: 1000 accuracy:  94.530%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E5B650> batch: 1200 accuracy:  94.508%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E59D90> batch: 1400 accuracy:  94.443%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E59D90> batch: 1600 accuracy:  94.356%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E593D0> batch: 1800 accuracy:  94.361%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 2000 accuracy:  94.390%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E59D90> batch: 2200 accuracy:  94.368%
# epoch: 7 loss: <built-in method item of Tensor object at 0x00000178A5E5B0B0> batch: 2400 accuracy:  94.463%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E5BA70> batch: 200 accuracy:  95.650%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E5A7B0> batch: 400 accuracy:  94.950%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E59D90> batch: 600 accuracy:  94.733%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E5B650> batch: 800 accuracy:  94.662%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 1000 accuracy:  94.500%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E59B50> batch: 1200 accuracy:  94.492%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E5B890> batch: 1400 accuracy:  94.471%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 1600 accuracy:  94.481%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E59A90> batch: 1800 accuracy:  94.644%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E593D0> batch: 2000 accuracy:  94.670%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E5B650> batch: 2200 accuracy:  94.673%
# epoch: 8 loss: <built-in method item of Tensor object at 0x00000178A5E593D0> batch: 2400 accuracy:  94.737%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 200 accuracy:  95.500%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5A7B0> batch: 400 accuracy:  95.325%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 600 accuracy:  95.317%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5A7B0> batch: 800 accuracy:  95.400%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 1000 accuracy:  95.230%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 1200 accuracy:  95.150%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5BA70> batch: 1400 accuracy:  95.157%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5AF90> batch: 1600 accuracy:  95.156%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E596D0> batch: 1800 accuracy:  95.028%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E593D0> batch: 2000 accuracy:  95.075%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5A7B0> batch: 2200 accuracy:  95.105%
# epoch: 9 loss: <built-in method item of Tensor object at 0x00000178A5E5BA70> batch: 2400 accuracy:  95.029%
#
# Duration: 11680 seconds

# %%
plt.plot(train_losses,label="train_losses")
plt.plot(test_losses,label="test_losses")
plt.legend()

# %% [markdown]
# # AlexNetModel

# %%
alex= models.alexnet(pretrained=True)

# %%
alex
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
for param in alex.parameters():
    param.requires_grad=False

# %%
torch.manual_seed(42)

alex.classifier=nn.Sequential(nn.Linear(9216,1024),
                                     nn.ReLU(),
                                     nn.Dropout(p=0.5),
                                     nn.Linear(1024,2),
                                     nn.LogSoftmax(dim=1))
alex
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Linear(in_features=9216, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1024, out_features=2, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %%
count_parameters(alex)
# Out:
#  9437184
#     1024
#     2048
#        2
# ________
#  9440258

# %%
criterion=nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(alex.classifier.parameters(),lr=0.001)

# %%
import time
start_time=time.time()
train_losses=[]
test_losses=[]
trn_correct=[]
tst_correct=[]

epochs=10
for i in range(epochs):
    trn_corr=0
    tst_corr=0
    for b, (X_train,y_train) in enumerate(train_loader):
        b+=1
        
        y_pred=alex(X_train)
        loss=criterion(y_pred,y_train)       
        #Update parameters
        predicted=torch.max(y_pred.data,1)[1]
        batch_corr=(predicted==y_train).sum()
        trn_corr+= batch_corr
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if b%200==0:
            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/8000]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%')
    
    loss=loss.detach().numpy()
    train_losses.append(loss)
    train_correct.append(trn_corr)
                  
    with torch.no_grad():
        for b, (X_test,y_test) in enumerate(test_loader):
            b+=1
                  
            y_val=alex(X_test)
            predicted=torch.max(y_val.data,1)[1]
            btach_corr=(predicted==y_test).sum()
            tst_corr+=btach_corr

    loss=criterion(y_val,y_test)
    loss=loss.detach().numpy()
    test_losses.append(loss)
    test_correct.append(tst_corr)
                  
print(f'\nDuration: {time.time() - start_time:.0f} seconds')
# Out:
# epoch:  0  batch:  200 [  2000/8000]  loss: 0.05267550  accuracy:  82.100%
# epoch:  0  batch:  400 [  4000/8000]  loss: 0.11317428  accuracy:  86.350%
# epoch:  0  batch:  600 [  6000/8000]  loss: 0.15899405  accuracy:  87.467%
# epoch:  0  batch:  800 [  8000/8000]  loss: 0.37226540  accuracy:  88.250%
# epoch:  0  batch: 1000 [ 10000/8000]  loss: 0.09884567  accuracy:  88.080%
# epoch:  0  batch: 1200 [ 12000/8000]  loss: 0.09021144  accuracy:  88.492%
# epoch:  0  batch: 1400 [ 14000/8000]  loss: 0.09132659  accuracy:  88.750%
# epoch:  0  batch: 1600 [ 16000/8000]  loss: 0.50606710  accuracy:  89.094%
# epoch:  0  batch: 1800 [ 18000/8000]  loss: 0.01190594  accuracy:  89.367%
# epoch:  0  batch: 2000 [ 20000/8000]  loss: 0.15160842  accuracy:  89.665%
# epoch:  0  batch: 2200 [ 22000/8000]  loss: 0.23386450  accuracy:  89.909%
# epoch:  0  batch: 2400 [ 24000/8000]  loss: 0.17886218  accuracy:  90.083%
# epoch:  1  batch:  200 [  2000/8000]  loss: 1.10033047  accuracy:  91.200%
# epoch:  1  batch:  400 [  4000/8000]  loss: 0.11706477  accuracy:  91.750%
# epoch:  1  batch:  600 [  6000/8000]  loss: 0.27960896  accuracy:  91.417%
# epoch:  1  batch:  800 [  8000/8000]  loss: 0.18896368  accuracy:  91.612%
# epoch:  1  batch: 1000 [ 10000/8000]  loss: 0.30371973  accuracy:  91.470%
# epoch:  1  batch: 1200 [ 12000/8000]  loss: 0.54027855  accuracy:  91.558%
# epoch:  1  batch: 1400 [ 14000/8000]  loss: 0.06126601  accuracy:  91.664%
# epoch:  1  batch: 1600 [ 16000/8000]  loss: 0.19678345  accuracy:  91.650%
# epoch:  1  batch: 1800 [ 18000/8000]  loss: 0.32817370  accuracy:  91.639%
# epoch:  1  batch: 2000 [ 20000/8000]  loss: 0.36944562  accuracy:  91.815%
# epoch:  1  batch: 2200 [ 22000/8000]  loss: 0.26641005  accuracy:  91.814%
# epoch:  1  batch: 2400 [ 24000/8000]  loss: 0.11367849  accuracy:  92.008%
# epoch:  2  batch:  200 [  2000/8000]  loss: 0.15868662  accuracy:  92.200%
# epoch:  2  batch:  400 [  4000/8000]  loss: 1.17230153  accuracy:  92.075%
# epoch:  2  batch:  600 [  6000/8000]  loss: 0.23396304  accuracy:  92.350%
# epoch:  2  batch:  800 [  8000/8000]  loss: 0.12540372  accuracy:  92.362%
# epoch:  2  batch: 1000 [ 10000/8000]  loss: 0.05511305  accuracy:  92.280%
# epoch:  2  batch: 1200 [ 12000/8000]  loss: 0.05972952  accuracy:  92.492%
# epoch:  2  batch: 1400 [ 14000/8000]  loss: 0.20248063  accuracy:  92.464%
# epoch:  2  batch: 1600 [ 16000/8000]  loss: 0.04394269  accuracy:  92.519%
# epoch:  2  batch: 1800 [ 18000/8000]  loss: 0.05727933  accuracy:  92.428%
# epoch:  2  batch: 2000 [ 20000/8000]  loss: 0.14961180  accuracy:  92.600%
# epoch:  2  batch: 2200 [ 22000/8000]  loss: 0.05575386  accuracy:  92.555%
# epoch:  2  batch: 2400 [ 24000/8000]  loss: 0.30498740  accuracy:  92.517%
# epoch:  3  batch:  200 [  2000/8000]  loss: 0.01363961  accuracy:  91.450%
# epoch:  3  batch:  400 [  4000/8000]  loss: 0.28045139  accuracy:  92.100%
# epoch:  3  batch:  600 [  6000/8000]  loss: 0.04057632  accuracy:  92.550%
# epoch:  3  batch:  800 [  8000/8000]  loss: 0.01476821  accuracy:  92.787%
# epoch:  3  batch: 1000 [ 10000/8000]  loss: 0.48832074  accuracy:  92.790%
# epoch:  3  batch: 1200 [ 12000/8000]  loss: 0.08122055  accuracy:  92.775%
# epoch:  3  batch: 1400 [ 14000/8000]  loss: 0.02616881  accuracy:  92.900%
# epoch:  3  batch: 1600 [ 16000/8000]  loss: 0.04090535  accuracy:  92.881%
# epoch:  3  batch: 1800 [ 18000/8000]  loss: 0.16686866  accuracy:  92.922%
# epoch:  3  batch: 2000 [ 20000/8000]  loss: 0.04663447  accuracy:  92.880%
# epoch:  3  batch: 2200 [ 22000/8000]  loss: 0.16538909  accuracy:  92.791%
# epoch:  3  batch: 2400 [ 24000/8000]  loss: 0.05175554  accuracy:  92.771%
# epoch:  4  batch:  200 [  2000/8000]  loss: 0.19977136  accuracy:  93.250%
# epoch:  4  batch:  400 [  4000/8000]  loss: 0.09693452  accuracy:  93.225%
# epoch:  4  batch:  600 [  6000/8000]  loss: 0.30482444  accuracy:  92.700%
# epoch:  4  batch:  800 [  8000/8000]  loss: 0.58171821  accuracy:  92.388%
# epoch:  4  batch: 1000 [ 10000/8000]  loss: 0.10606323  accuracy:  92.740%
# epoch:  4  batch: 1200 [ 12000/8000]  loss: 0.45214161  accuracy:  92.817%
# epoch:  4  batch: 1400 [ 14000/8000]  loss: 0.26922524  accuracy:  92.793%
# epoch:  4  batch: 1600 [ 16000/8000]  loss: 0.31937638  accuracy:  92.812%
# epoch:  4  batch: 1800 [ 18000/8000]  loss: 0.07696134  accuracy:  92.917%
# epoch:  4  batch: 2000 [ 20000/8000]  loss: 0.34451404  accuracy:  92.815%
# epoch:  4  batch: 2200 [ 22000/8000]  loss: 0.21594182  accuracy:  92.850%
# epoch:  4  batch: 2400 [ 24000/8000]  loss: 0.13717054  accuracy:  92.838%
# epoch:  5  batch:  200 [  2000/8000]  loss: 0.17229487  accuracy:  92.900%
# epoch:  5  batch:  400 [  4000/8000]  loss: 0.07582559  accuracy:  92.775%
# epoch:  5  batch:  600 [  6000/8000]  loss: 0.35085174  accuracy:  92.800%
# epoch:  5  batch:  800 [  8000/8000]  loss: 0.11750835  accuracy:  93.025%
# epoch:  5  batch: 1000 [ 10000/8000]  loss: 0.02692038  accuracy:  92.970%
# epoch:  5  batch: 1200 [ 12000/8000]  loss: 0.21913564  accuracy:  93.067%
# epoch:  5  batch: 1400 [ 14000/8000]  loss: 0.17922945  accuracy:  92.950%
# epoch:  5  batch: 1600 [ 16000/8000]  loss: 0.07591499  accuracy:  92.950%
# epoch:  5  batch: 1800 [ 18000/8000]  loss: 0.05256370  accuracy:  92.950%
# epoch:  5  batch: 2000 [ 20000/8000]  loss: 0.12960826  accuracy:  92.950%
# epoch:  5  batch: 2200 [ 22000/8000]  loss: 0.14864449  accuracy:  92.955%
# epoch:  5  batch: 2400 [ 24000/8000]  loss: 0.04206886  accuracy:  93.021%
# epoch:  6  batch:  200 [  2000/8000]  loss: 0.71351916  accuracy:  93.850%
# epoch:  6  batch:  400 [  4000/8000]  loss: 0.22301862  accuracy:  93.725%
# epoch:  6  batch:  600 [  6000/8000]  loss: 0.29534143  accuracy:  93.683%
# epoch:  6  batch:  800 [  8000/8000]  loss: 0.15289354  accuracy:  93.650%
# epoch:  6  batch: 1000 [ 10000/8000]  loss: 0.32939643  accuracy:  93.440%
# epoch:  6  batch: 1200 [ 12000/8000]  loss: 0.40723571  accuracy:  93.300%
# epoch:  6  batch: 1400 [ 14000/8000]  loss: 0.45582765  accuracy:  93.157%
# epoch:  6  batch: 1600 [ 16000/8000]  loss: 0.09198870  accuracy:  93.181%
# epoch:  6  batch: 1800 [ 18000/8000]  loss: 0.06222302  accuracy:  93.228%
# epoch:  6  batch: 2000 [ 20000/8000]  loss: 0.18899122  accuracy:  93.240%
# epoch:  6  batch: 2200 [ 22000/8000]  loss: 0.06446619  accuracy:  93.291%
# epoch:  6  batch: 2400 [ 24000/8000]  loss: 0.45874029  accuracy:  93.250%
# epoch:  7  batch:  200 [  2000/8000]  loss: 0.23690173  accuracy:  93.450%
# epoch:  7  batch:  400 [  4000/8000]  loss: 0.19628586  accuracy:  93.625%
# epoch:  7  batch:  600 [  6000/8000]  loss: 0.11531357  accuracy:  93.450%
# epoch:  7  batch:  800 [  8000/8000]  loss: 0.08626900  accuracy:  93.237%
# epoch:  7  batch: 1000 [ 10000/8000]  loss: 0.29550186  accuracy:  93.280%
# epoch:  7  batch: 1200 [ 12000/8000]  loss: 0.45761243  accuracy:  93.283%
# epoch:  7  batch: 1400 [ 14000/8000]  loss: 0.10747985  accuracy:  93.407%
# epoch:  7  batch: 1600 [ 16000/8000]  loss: 0.14453191  accuracy:  93.450%
# epoch:  7  batch: 1800 [ 18000/8000]  loss: 0.01385132  accuracy:  93.350%
# epoch:  7  batch: 2000 [ 20000/8000]  loss: 0.24235734  accuracy:  93.220%
# epoch:  7  batch: 2200 [ 22000/8000]  loss: 0.06163715  accuracy:  93.241%
# epoch:  7  batch: 2400 [ 24000/8000]  loss: 0.01803489  accuracy:  93.329%
# epoch:  8  batch:  200 [  2000/8000]  loss: 0.01990566  accuracy:  93.450%
# epoch:  8  batch:  400 [  4000/8000]  loss: 0.09480450  accuracy:  93.300%
# epoch:  8  batch:  600 [  6000/8000]  loss: 0.14912441  accuracy:  93.283%
# epoch:  8  batch:  800 [  8000/8000]  loss: 0.11360172  accuracy:  93.287%
# epoch:  8  batch: 1000 [ 10000/8000]  loss: 0.13085875  accuracy:  93.230%
# epoch:  8  batch: 1200 [ 12000/8000]  loss: 0.15405168  accuracy:  93.142%
# epoch:  8  batch: 1400 [ 14000/8000]  loss: 0.11837880  accuracy:  93.214%
# epoch:  8  batch: 1600 [ 16000/8000]  loss: 0.08924673  accuracy:  93.188%
# epoch:  8  batch: 1800 [ 18000/8000]  loss: 0.00493792  accuracy:  93.278%
# epoch:  8  batch: 2000 [ 20000/8000]  loss: 0.05195879  accuracy:  93.315%
# epoch:  8  batch: 2200 [ 22000/8000]  loss: 0.13895243  accuracy:  93.286%
# epoch:  8  batch: 2400 [ 24000/8000]  loss: 0.38036376  accuracy:  93.308%
# epoch:  9  batch:  200 [  2000/8000]  loss: 0.28190395  accuracy:  92.750%
# epoch:  9  batch:  400 [  4000/8000]  loss: 0.25708991  accuracy:  93.375%
# epoch:  9  batch:  600 [  6000/8000]  loss: 0.01551135  accuracy:  93.650%
# epoch:  9  batch:  800 [  8000/8000]  loss: 0.09196757  accuracy:  93.650%
# epoch:  9  batch: 1000 [ 10000/8000]  loss: 0.08186944  accuracy:  93.650%
# epoch:  9  batch: 1200 [ 12000/8000]  loss: 0.13380089  accuracy:  93.683%
# epoch:  9  batch: 1400 [ 14000/8000]  loss: 0.14506738  accuracy:  93.607%
# epoch:  9  batch: 1600 [ 16000/8000]  loss: 0.09120915  accuracy:  93.644%
# epoch:  9  batch: 1800 [ 18000/8000]  loss: 0.16560672  accuracy:  93.528%
# epoch:  9  batch: 2000 [ 20000/8000]  loss: 1.08650672  accuracy:  93.555%
# epoch:  9  batch: 2200 [ 22000/8000]  loss: 0.01627519  accuracy:  93.505%
# epoch:  9  batch: 2400 [ 24000/8000]  loss: 0.13844527  accuracy:  93.483%
#
# Duration: 11741 seconds

# %% [markdown]
# # Prediction

# %%
device = torch.device("cpu")   #"cuda:0"

# %%
mycnn.eval()
y_true=[]
y_pred=[]
with torch.no_grad():
    for test_data in test_loader:
        test_images, test_labels = test_data[0].to(device), test_data[1].to(device)
        pred = mycnn(test_images).argmax(dim=1)
        for i in range(len(pred)):
            y_true.append(test_labels[i].item())
            y_pred.append(pred[i].item())
print(y_pred[0:5])
# Out:
# [0, 0, 0, 0, 0]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true,y_pred,target_names=class_names,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  parasitized     0.9357    0.9400    0.9378      1300
#   uninfected     0.9397    0.9354    0.9375      1300
#
#     accuracy                         0.9377      2600
#    macro avg     0.9377    0.9377    0.9377      2600
# weighted avg     0.9377    0.9377    0.9377      2600

# %%
alex.eval()
ay_true=[]
ay_pred=[]
with torch.no_grad():
    for test_data in test_loader:
        test_images, test_labels = test_data[0].to(device), test_data[1].to(device)
        pred = alex(test_images).argmax(dim=1)
        for i in range(len(pred)):
            ay_true.append(test_labels[i].item())
            ay_pred.append(pred[i].item())
print(ay_pred[0:5])
# Out:
# [0, 0, 0, 0, 0]

# %%
from sklearn.metrics import classification_report
print(classification_report(ay_true,ay_pred,target_names=class_names,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  parasitized     0.9462    0.9338    0.9400      1300
#   uninfected     0.9347    0.9469    0.9408      1300
#
#     accuracy                         0.9404      2600
#    macro avg     0.9405    0.9404    0.9404      2600
# weighted avg     0.9405    0.9404    0.9404      2600
